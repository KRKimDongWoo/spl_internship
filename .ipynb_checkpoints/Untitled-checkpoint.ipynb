# %%
import torch
import torchvision
from src.graph.anchor_graph import *
from src.builder import *
from src.trainer import *
from src.storage import *
from src.transformer import *
from src.generator import *

# %%
storage = Storage('./tests')
gen = Generator((3, 32, 32), (10,), storage)

# %%
gen.generate()
# Out:
# (0, ['added init block'])

# %%
for i in range(10):
    print(gen.generate(i))
# Out:
# (1, ['deeper layer on 6', 'skip con from 5 to 16'])
# (2, ['conv wider on 15'])
# (3, ['conv wider on 5'])
# (4, ['deeper layer on 16', 'conv wider on 5', 'skip con from 15 to 25', 'conv wider on 20', 'skip con from 20 to 25'])
# (5, ['conv wider on 5', 'skip con from 5 to 16', 'skip con from 15 to 25', 'conv wider on 33', 'conv wider on 37'])
# (6, ['conv wider on 29', 'skip con from 29 to 25', 'conv wider on 33', 'skip con from 33 to 16', 'skip con from 41 to 25', 'conv wider on 45', 'conv wider on 53'])
# (7, ['deeper layer on 6', 'conv wider on 5', 'conv wider on 15', 'conv wider on 24', 'skip con from 37 to 16', 'skip con from 41 to 6', 'conv wider on 49', 'conv wider on 61', 'conv wider on 65', 'skip con from 65 to 25', 'conv wider on 69', 'skip con from 69 to 70'])
# ...

# %%
gr2 = gen.load_graph(5)

# %%
gr2.visualize('./', 'test')

# %%
x = torch.rand(1, 3, 32, 32)

# %%
ModelBuilder(gr2).build()(x)
# Out:
# tensor([[ 0.0000, -1.8696,  0.0000, -1.7432, -0.7114, -0.0000,  0.0000,  0.5863,
#          -0.0000,  0.4592]], grad_fn=<MulBackward0>)

# %%
transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor(),
                                            torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, num_workers=2)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=False, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
trainer = ModelTrainer(5, 
                       torch.nn.CrossEntropyLoss, 
                       torch.optim.SGD, 
                       trainloader, testloader)

# %%
trainer.fit(storage.load(0))
# Out:
# epoch 0/5 ******************** train_loss: 28058.648584127426
# epoch 1/5 ************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6f5feb9f0391> in <module>
# ----> 1 trainer.fit(storage.load(0))
#
# ~/development/UROP/spl_internship/src/trainer.py in fit(self, graph)
#      67         self.optimizer = self.opt_class(net.parameters(), lr=1e-4, momentum=0.9)
#      68
# ---> 69         self.train(net)
#      70         accuracy = self.test(net)
#
# ~/development/UROP/spl_internship/src/trainer.py in train(self, net)
#      42                 outputs = net(inputs)
#      43                 loss = self.criterion(outputs, labels)
# ---> 44                 loss.backward()
#      45                 self.optimizer.step()
#      46
#
# ~/development/UROP/env/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
# ...

# %%
import fastai
import fastai.vision

# %%
cifar10 = untar_data(URLs.CIFAR)
