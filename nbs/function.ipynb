# %%
#export
from math import ceil
import numpy as np
from .constants import NEXT_CHANNEL
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5f2eef4be454> in <module>
#       1 #export
#       2 from math import ceil
# ----> 3 from .constant import NEXT_CHANNEL
#
# ModuleNotFoundError: No module named '__main__.constant'; '__main__' is not a package

# %%
from math import ceil
from include.constants import NEXT_CHANNEL
import numpy as np

# %%
#export
def ceil_power_of_two(x):
    x = ceil(x) - 1
    res = 0
    while x > 0:
        x = x // 2
        res = res + 1
        
    return 2**(res)

# %%
#export
def next_channel(ni):
    if ni in NEXT_CHANNEL:
        return NEXT_CHANNEL[ni]
    else:
        for key in NEXT_CHANNEL.keys():
            next = NEXT_CHANNEL[key]
            if key <= ni and ni < next:
                return next
        return ni

# %%
#export
def rand_bool(p=0.5):
    return np.random.choice([True, False], p=[p, 1-p])

def rand_geo(p):
    return np.random.geometric(p=p)

# %%
ceil_power_of_two(127/8)
# Out:
# 16

# %%
# !python nb2py.py function.ipynb
# Out:
# Converted function.ipynb to exp/nb_function.py
