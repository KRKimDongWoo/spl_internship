# %%
from fastai.vision import *
from include.graph.graph import *
from include.graph_transformer import *

# %% [markdown]
# ## Vanilla CNN

# %%
path = untar_data(URLs.MNIST)

# %%
data = ImageList.from_folder(path, convert_mode="L").split_by_folder(train="training", valid="testing").label_from_folder().databunch(bs=128)

# %%
gr = Graph(input_shape=(1, 28, 28), output_shape=(10,))

# %%
next = add_conv_block(gr, gr.input, nf=16, ks=3)

# %%
next = add_conv_block(gr, next, nf=32, ks=3)

# %%
next = add_flatten_layer(gr, next)

# %%
next = add_linear_layer(gr, next, no=4*7*7)

# %%
next = add_linear_layer(gr, next, gr.output, no=10)

# %%
gr.visualize('cnn', './')

# %%
module = gr.generate_model()

# %%
learn = Learner(data, module, loss_func=nn.CrossEntropyLoss(), metrics=accuracy)

# %%
learn.summary()
# Out:
# Generator
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [16, 28, 28]         144        True
# ______________________________________________________________________
# BatchNorm2d          [16, 28, 28]         32         True
# ______________________________________________________________________
# ReLU                 [16, 28, 28]         0          False
# ______________________________________________________________________
# Conv2d               [32, 28, 28]         4,608      True
# ______________________________________________________________________
# BatchNorm2d          [32, 28, 28]         64         True
# ______________________________________________________________________
# ReLU                 [32, 28, 28]         0          False
# ______________________________________________________________________
# Flatten              [25088]              0          False
# ______________________________________________________________________
# Linear               [196]                4,917,444  True
# ______________________________________________________________________
# Linear               [10]                 1,970      True
# ______________________________________________________________________
#
# Total params: 4,924,262
# Total trainable params: 4,924,262
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : CrossEntropyLoss
# ======================================================================
# Callbacks functions applied

# %% [markdown]
# ## ResNet CNN

# %%
path_cifar = untar_data(URLs.CIFAR)

# %%
data_cifar = ImageList.from_folder(path_cifar).split_by_folder(train="train", valid="test").label_from_folder().databunch(bs=128)

# %%
gr_cifar = Graph((3, 32, 32), (10,))

# %%
add_res_net(gr_cifar, gr_cifar.input, gr_cifar.output, 1, [2, 2, 2, 2])
# Out:
# 2

# %%
gr_cifar.visualize('res', './')

# %%
module = gr_cifar.generate_model()

# %%
learn = Learner(data_cifar, module, loss_func=nn.CrossEntropyLoss(), metrics=accuracy)

# %%
learn.summary()
# Out:
# Generator
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [64, 16, 16]         9,408      True
# ______________________________________________________________________
# BatchNorm2d          [64, 16, 16]         128        True
# ______________________________________________________________________
# ReLU                 [64, 16, 16]         0          False
# ______________________________________________________________________
# MaxPool2d            [64, 8, 8]           0          False
# ______________________________________________________________________
# Conv2d               [64, 8, 8]           36,864     True
# ______________________________________________________________________
# BatchNorm2d          [64, 8, 8]           128        True
# ______________________________________________________________________
# ReLU                 [64, 8, 8]           0          False
# ______________________________________________________________________
# Conv2d               [64, 8, 8]           36,864     True
# ______________________________________________________________________
# BatchNorm2d          [64, 8, 8]           128        True
# ______________________________________________________________________
# Add                  [64, 8, 8]           0          False
# ______________________________________________________________________
# Conv2d               [64, 8, 8]           36,864     True
# ______________________________________________________________________
# BatchNorm2d          [64, 8, 8]           128        True
# ______________________________________________________________________
# ReLU                 [64, 8, 8]           0          False
# ______________________________________________________________________
# Conv2d               [64, 8, 8]           36,864     True
# ______________________________________________________________________
# BatchNorm2d          [64, 8, 8]           128        True
# ______________________________________________________________________
# Add                  [64, 8, 8]           0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          73,728     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# ReLU                 [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          147,456    True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# AvgPool2d            [64, 4, 4]           0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          8,320      True
# ______________________________________________________________________
# Add                  [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          147,456    True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# ReLU                 [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          147,456    True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# Add                  [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [256, 2, 2]          294,912    True
# ______________________________________________________________________
# BatchNorm2d          [256, 2, 2]          512        True
# ______________________________________________________________________
# ReLU                 [256, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [256, 2, 2]          589,824    True
# ______________________________________________________________________
# BatchNorm2d          [256, 2, 2]          512        True
# ______________________________________________________________________
# AvgPool2d            [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [256, 2, 2]          33,024     True
# ______________________________________________________________________
# Add                  [256, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [256, 2, 2]          589,824    True
# ______________________________________________________________________
# BatchNorm2d          [256, 2, 2]          512        True
# ______________________________________________________________________
# ReLU                 [256, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [256, 2, 2]          589,824    True
# ______________________________________________________________________
# BatchNorm2d          [256, 2, 2]          512        True
# ______________________________________________________________________
# Add                  [256, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [512, 1, 1]          1,179,648  True
# ______________________________________________________________________
# BatchNorm2d          [512, 1, 1]          1,024      True
# ______________________________________________________________________
# ReLU                 [512, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [512, 1, 1]          2,359,296  True
# ______________________________________________________________________
# BatchNorm2d          [512, 1, 1]          1,024      True
# ______________________________________________________________________
# AvgPool2d            [256, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [512, 1, 1]          131,584    True
# ______________________________________________________________________
# Add                  [512, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [512, 1, 1]          2,359,296  True
# ______________________________________________________________________
# BatchNorm2d          [512, 1, 1]          1,024      True
# ______________________________________________________________________
# ReLU                 [512, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [512, 1, 1]          2,359,296  True
# ______________________________________________________________________
# BatchNorm2d          [512, 1, 1]          1,024      True
# ______________________________________________________________________
# Add                  [512, 1, 1]          0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [512, 1, 1]          0          False
# ______________________________________________________________________
# Flatten              [512]                0          False
# ______________________________________________________________________
# Linear               [10]                 5,130      True
# ______________________________________________________________________
#
# Total params: 11,180,746
# Total trainable params: 11,180,746
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : CrossEntropyLoss
# ======================================================================
# Callbacks functions applied

# %% [markdown]
# ## DenseNet CNN

# %%
path_cifar = untar_data(URLs.CIFAR)

# %%
data_cifar = ImageList.from_folder(path_cifar).split_by_folder(train="train", valid="test").label_from_folder().databunch(bs=128)

# %%
gr_cifar = Graph((3, 32, 32), (10,))

# %%
add_dense_net(gr_cifar, gr_cifar.input, gr_cifar.output)
# Out:
# 2

# %%
gr_cifar.visualize('dense', './')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-5e6c58e2536b> in <module>
# ----> 1 gr_cifar.visualize('dense', './')
#
# ~/development/spl_internship/nbs/include/graph/graph.py in visualize(self, filename, path)
#      82         digraph.filename=filename
#      83         digraph.directory=path
# ---> 84         digraph.render(view=False)
#      85
#      86     def _node_as_layer(self, id):
#
# ~/development/.env/env_1/local/lib/python3.6/site-packages/graphviz/files.py in render(self, filename, directory, view, cleanup, format, renderer, formatter, quiet)
#     199         rendered = backend.render(self._engine, format, filepath,
#     200                                   renderer=renderer, formatter=formatter,
# --> 201                                   quiet=quiet)
#     202
#     203         if cleanup:
#
# ~/development/.env/env_1/local/lib/python3.6/site-packages/graphviz/backend.py in render(engine, format, filepath, renderer, formatter, quiet)
#     198     else:
#     199         cwd = None
# --> 200     run(cmd, capture_output=True, cwd=cwd, check=True, quiet=quiet)
#     201     return rendered
#     202
#
# ~/development/.env/env_1/local/lib/python3.6/site-packages/graphviz/backend.py in run(cmd, input, capture_output, check, quiet, **kwargs)
#     158             raise
#     159
# --> 160     out, err = proc.communicate(input)
#     161
#     162     if not quiet and err:
#
# /usr/lib/python3.6/subprocess.py in communicate(self, input, timeout)
#     861
#     862             try:
# --> 863                 stdout, stderr = self._communicate(input, endtime, timeout)
#     864             finally:
#     865                 self._communication_started = True
#
# /usr/lib/python3.6/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1532                         raise TimeoutExpired(self.args, orig_timeout)
#    1533
# -> 1534                     ready = selector.select(timeout)
#    1535                     self._check_timeout(endtime, orig_timeout)
#    1536
#
# /usr/lib/python3.6/selectors.py in select(self, timeout)
#     374             ready = []
#     375             try:
# --> 376                 fd_event_list = self._poll.poll(timeout)
#     377             except InterruptedError:
#     378                 return ready
#
# KeyboardInterrupt:

# %%
module = gr_cifar.generate_model()

# %%
learn = Learner(data_cifar, module, loss_func=nn.CrossEntropyLoss(), metrics=accuracy)

# %%
learn.summary()
# Out:
# Generator
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [64, 16, 16]         9,408      True
# ______________________________________________________________________
# MaxPool2d            [64, 8, 8]           0          False
# ______________________________________________________________________
# BatchNorm2d          [64, 8, 8]           128        True
# ______________________________________________________________________
# ReLU                 [64, 8, 8]           0          False
# ______________________________________________________________________
# Conv2d               [128, 8, 8]          8,192      True
# ______________________________________________________________________
# BatchNorm2d          [128, 8, 8]          256        True
# ______________________________________________________________________
# ReLU                 [128, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [32, 8, 8]           36,864     True
# ______________________________________________________________________
# Concat               [96, 8, 8]           0          False
# ______________________________________________________________________
# BatchNorm2d          [96, 8, 8]           192        True
# ______________________________________________________________________
# ReLU                 [96, 8, 8]           0          False
# ______________________________________________________________________
# Conv2d               [128, 8, 8]          12,288     True
# ______________________________________________________________________
# BatchNorm2d          [128, 8, 8]          256        True
# ______________________________________________________________________
# ReLU                 [128, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [32, 8, 8]           36,864     True
# ______________________________________________________________________
# Concat               [128, 8, 8]          0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 8, 8]          256        True
# ______________________________________________________________________
# ReLU                 [128, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [128, 8, 8]          16,384     True
# ______________________________________________________________________
# BatchNorm2d          [128, 8, 8]          256        True
# ______________________________________________________________________
# ReLU                 [128, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [32, 8, 8]           36,864     True
# ______________________________________________________________________
# Concat               [160, 8, 8]          0          False
# ______________________________________________________________________
# BatchNorm2d          [160, 8, 8]          320        True
# ______________________________________________________________________
# ReLU                 [160, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [128, 8, 8]          20,480     True
# ______________________________________________________________________
# BatchNorm2d          [128, 8, 8]          256        True
# ______________________________________________________________________
# ReLU                 [128, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [32, 8, 8]           36,864     True
# ______________________________________________________________________
# Concat               [192, 8, 8]          0          False
# ______________________________________________________________________
# BatchNorm2d          [192, 8, 8]          384        True
# ______________________________________________________________________
# ReLU                 [192, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [128, 8, 8]          24,576     True
# ______________________________________________________________________
# BatchNorm2d          [128, 8, 8]          256        True
# ______________________________________________________________________
# ReLU                 [128, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [32, 8, 8]           36,864     True
# ______________________________________________________________________
# Concat               [224, 8, 8]          0          False
# ______________________________________________________________________
# BatchNorm2d          [224, 8, 8]          448        True
# ______________________________________________________________________
# ReLU                 [224, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [128, 8, 8]          28,672     True
# ______________________________________________________________________
# BatchNorm2d          [128, 8, 8]          256        True
# ______________________________________________________________________
# ReLU                 [128, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [32, 8, 8]           36,864     True
# ______________________________________________________________________
# Concat               [256, 8, 8]          0          False
# ______________________________________________________________________
# BatchNorm2d          [256, 8, 8]          512        True
# ______________________________________________________________________
# ReLU                 [256, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [128, 8, 8]          32,768     True
# ______________________________________________________________________
# AvgPool2d            [128, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# ReLU                 [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          16,384     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# ReLU                 [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [32, 4, 4]           36,864     True
# ______________________________________________________________________
# Concat               [160, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [160, 4, 4]          320        True
# ______________________________________________________________________
# ReLU                 [160, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          20,480     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# ReLU                 [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [32, 4, 4]           36,864     True
# ______________________________________________________________________
# Concat               [192, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [192, 4, 4]          384        True
# ______________________________________________________________________
# ReLU                 [192, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          24,576     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# ReLU                 [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [32, 4, 4]           36,864     True
# ______________________________________________________________________
# Concat               [224, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [224, 4, 4]          448        True
# ______________________________________________________________________
# ReLU                 [224, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          28,672     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# ReLU                 [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [32, 4, 4]           36,864     True
# ______________________________________________________________________
# Concat               [256, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [256, 4, 4]          512        True
# ______________________________________________________________________
# ReLU                 [256, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          32,768     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# ReLU                 [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [32, 4, 4]           36,864     True
# ______________________________________________________________________
# Concat               [288, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [288, 4, 4]          576        True
# ______________________________________________________________________
# ReLU                 [288, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          36,864     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# ReLU                 [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [32, 4, 4]           36,864     True
# ______________________________________________________________________
# Concat               [320, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [320, 4, 4]          640        True
# ______________________________________________________________________
# ReLU                 [320, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          40,960     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# ReLU                 [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [32, 4, 4]           36,864     True
# ______________________________________________________________________
# Concat               [352, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [352, 4, 4]          704        True
# ______________________________________________________________________
# ReLU                 [352, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          45,056     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# ReLU                 [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [32, 4, 4]           36,864     True
# ______________________________________________________________________
# Concat               [384, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [384, 4, 4]          768        True
# ______________________________________________________________________
# ReLU                 [384, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          49,152     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# ReLU                 [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [32, 4, 4]           36,864     True
# ______________________________________________________________________
# Concat               [416, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [416, 4, 4]          832        True
# ______________________________________________________________________
# ReLU                 [416, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          53,248     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# ReLU                 [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [32, 4, 4]           36,864     True
# ______________________________________________________________________
# Concat               [448, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [448, 4, 4]          896        True
# ______________________________________________________________________
# ReLU                 [448, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          57,344     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# ReLU                 [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [32, 4, 4]           36,864     True
# ______________________________________________________________________
# Concat               [480, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [480, 4, 4]          960        True
# ______________________________________________________________________
# ReLU                 [480, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          61,440     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# ReLU                 [128, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [32, 4, 4]           36,864     True
# ______________________________________________________________________
# Concat               [512, 4, 4]          0          False
# ______________________________________________________________________
# BatchNorm2d          [512, 4, 4]          1,024      True
# ______________________________________________________________________
# ReLU                 [512, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [256, 4, 4]          131,072    True
# ______________________________________________________________________
# AvgPool2d            [256, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [256, 2, 2]          512        True
# ______________________________________________________________________
# ReLU                 [256, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          32,768     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [288, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [288, 2, 2]          576        True
# ______________________________________________________________________
# ReLU                 [288, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          36,864     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [320, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [320, 2, 2]          640        True
# ______________________________________________________________________
# ReLU                 [320, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          40,960     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [352, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [352, 2, 2]          704        True
# ______________________________________________________________________
# ReLU                 [352, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          45,056     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [384, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [384, 2, 2]          768        True
# ______________________________________________________________________
# ReLU                 [384, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          49,152     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [416, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [416, 2, 2]          832        True
# ______________________________________________________________________
# ReLU                 [416, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          53,248     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [448, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [448, 2, 2]          896        True
# ______________________________________________________________________
# ReLU                 [448, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          57,344     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [480, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [480, 2, 2]          960        True
# ______________________________________________________________________
# ReLU                 [480, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          61,440     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [512, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [512, 2, 2]          1,024      True
# ______________________________________________________________________
# ReLU                 [512, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          65,536     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [544, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [544, 2, 2]          1,088      True
# ______________________________________________________________________
# ReLU                 [544, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          69,632     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [576, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [576, 2, 2]          1,152      True
# ______________________________________________________________________
# ReLU                 [576, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          73,728     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [608, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [608, 2, 2]          1,216      True
# ______________________________________________________________________
# ReLU                 [608, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          77,824     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [640, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [640, 2, 2]          1,280      True
# ______________________________________________________________________
# ReLU                 [640, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          81,920     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [672, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [672, 2, 2]          1,344      True
# ______________________________________________________________________
# ReLU                 [672, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          86,016     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [704, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [704, 2, 2]          1,408      True
# ______________________________________________________________________
# ReLU                 [704, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          90,112     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [736, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [736, 2, 2]          1,472      True
# ______________________________________________________________________
# ReLU                 [736, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          94,208     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [768, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [768, 2, 2]          1,536      True
# ______________________________________________________________________
# ReLU                 [768, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          98,304     True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [800, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [800, 2, 2]          1,600      True
# ______________________________________________________________________
# ReLU                 [800, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          102,400    True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [832, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [832, 2, 2]          1,664      True
# ______________________________________________________________________
# ReLU                 [832, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          106,496    True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [864, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [864, 2, 2]          1,728      True
# ______________________________________________________________________
# ReLU                 [864, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          110,592    True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [896, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [896, 2, 2]          1,792      True
# ______________________________________________________________________
# ReLU                 [896, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          114,688    True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [928, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [928, 2, 2]          1,856      True
# ______________________________________________________________________
# ReLU                 [928, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          118,784    True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [960, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [960, 2, 2]          1,920      True
# ______________________________________________________________________
# ReLU                 [960, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          122,880    True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [992, 2, 2]          0          False
# ______________________________________________________________________
# BatchNorm2d          [992, 2, 2]          1,984      True
# ______________________________________________________________________
# ReLU                 [992, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [128, 2, 2]          126,976    True
# ______________________________________________________________________
# BatchNorm2d          [128, 2, 2]          256        True
# ______________________________________________________________________
# ReLU                 [128, 2, 2]          0          False
# ______________________________________________________________________
# Conv2d               [32, 2, 2]           36,864     True
# ______________________________________________________________________
# Concat               [1024, 2, 2]         0          False
# ______________________________________________________________________
# BatchNorm2d          [1024, 2, 2]         2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 2, 2]         0          False
# ______________________________________________________________________
# Conv2d               [512, 2, 2]          524,288    True
# ______________________________________________________________________
# AvgPool2d            [512, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [512, 1, 1]          1,024      True
# ______________________________________________________________________
# ReLU                 [512, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          65,536     True
# ______________________________________________________________________
# BatchNorm2d          [128, 1, 1]          256        True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           36,864     True
# ______________________________________________________________________
# Concat               [544, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [544, 1, 1]          1,088      True
# ______________________________________________________________________
# ReLU                 [544, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          69,632     True
# ______________________________________________________________________
# BatchNorm2d          [128, 1, 1]          256        True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           36,864     True
# ______________________________________________________________________
# Concat               [576, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [576, 1, 1]          1,152      True
# ______________________________________________________________________
# ReLU                 [576, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          73,728     True
# ______________________________________________________________________
# BatchNorm2d          [128, 1, 1]          256        True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           36,864     True
# ______________________________________________________________________
# Concat               [608, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [608, 1, 1]          1,216      True
# ______________________________________________________________________
# ReLU                 [608, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          77,824     True
# ______________________________________________________________________
# BatchNorm2d          [128, 1, 1]          256        True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           36,864     True
# ______________________________________________________________________
# Concat               [640, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [640, 1, 1]          1,280      True
# ______________________________________________________________________
# ReLU                 [640, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          81,920     True
# ______________________________________________________________________
# BatchNorm2d          [128, 1, 1]          256        True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           36,864     True
# ______________________________________________________________________
# Concat               [672, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [672, 1, 1]          1,344      True
# ______________________________________________________________________
# ReLU                 [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          86,016     True
# ______________________________________________________________________
# BatchNorm2d          [128, 1, 1]          256        True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           36,864     True
# ______________________________________________________________________
# Concat               [704, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [704, 1, 1]          1,408      True
# ______________________________________________________________________
# ReLU                 [704, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          90,112     True
# ______________________________________________________________________
# BatchNorm2d          [128, 1, 1]          256        True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           36,864     True
# ______________________________________________________________________
# Concat               [736, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [736, 1, 1]          1,472      True
# ______________________________________________________________________
# ReLU                 [736, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          94,208     True
# ______________________________________________________________________
# BatchNorm2d          [128, 1, 1]          256        True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           36,864     True
# ______________________________________________________________________
# Concat               [768, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [768, 1, 1]          1,536      True
# ______________________________________________________________________
# ReLU                 [768, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          98,304     True
# ______________________________________________________________________
# BatchNorm2d          [128, 1, 1]          256        True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           36,864     True
# ______________________________________________________________________
# Concat               [800, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [800, 1, 1]          1,600      True
# ______________________________________________________________________
# ReLU                 [800, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          102,400    True
# ______________________________________________________________________
# BatchNorm2d          [128, 1, 1]          256        True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           36,864     True
# ______________________________________________________________________
# Concat               [832, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [832, 1, 1]          1,664      True
# ______________________________________________________________________
# ReLU                 [832, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          106,496    True
# ______________________________________________________________________
# BatchNorm2d          [128, 1, 1]          256        True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           36,864     True
# ______________________________________________________________________
# Concat               [864, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [864, 1, 1]          1,728      True
# ______________________________________________________________________
# ReLU                 [864, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          110,592    True
# ______________________________________________________________________
# BatchNorm2d          [128, 1, 1]          256        True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           36,864     True
# ______________________________________________________________________
# Concat               [896, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [896, 1, 1]          1,792      True
# ______________________________________________________________________
# ReLU                 [896, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          114,688    True
# ______________________________________________________________________
# BatchNorm2d          [128, 1, 1]          256        True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           36,864     True
# ______________________________________________________________________
# Concat               [928, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [928, 1, 1]          1,856      True
# ______________________________________________________________________
# ReLU                 [928, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          118,784    True
# ______________________________________________________________________
# BatchNorm2d          [128, 1, 1]          256        True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           36,864     True
# ______________________________________________________________________
# Concat               [960, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [960, 1, 1]          1,920      True
# ______________________________________________________________________
# ReLU                 [960, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          122,880    True
# ______________________________________________________________________
# BatchNorm2d          [128, 1, 1]          256        True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           36,864     True
# ______________________________________________________________________
# Concat               [992, 1, 1]          0          False
# ______________________________________________________________________
# BatchNorm2d          [992, 1, 1]          1,984      True
# ______________________________________________________________________
# ReLU                 [992, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [128, 1, 1]          126,976    True
# ______________________________________________________________________
# BatchNorm2d          [128, 1, 1]          256        True
# ______________________________________________________________________
# ReLU                 [128, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           36,864     True
# ______________________________________________________________________
# Concat               [1024, 1, 1]         0          False
# ______________________________________________________________________
# BatchNorm2d          [1024, 1, 1]         2,048      True
# ______________________________________________________________________
# Flatten              [1024]               0          False
# ______________________________________________________________________
# Linear               [10]                 10,250     True
# ______________________________________________________________________
#
# Total params: 6,963,978
# Total trainable params: 6,963,978
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : CrossEntropyLoss
# ======================================================================
# Callbacks functions applied
